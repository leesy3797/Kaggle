# %% [markdown]
# # Imports and configs

# %%
# !pip install -U autogluon.tabular
# !pip install ray==2.10.0
# Out:
# Collecting autogluon.tabular
#   Downloading autogluon.tabular-1.1.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<1.29,>=1.21 in /opt/conda/lib/python3.10/site-packages (from autogluon.tabular) (1.26.4)
# Collecting scipy<1.13,>=1.5.4 (from autogluon.tabular)
#   Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas<2.3.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from autogluon.tabular) (2.2.3)
# Collecting scikit-learn<1.4.1,>=1.3.0 (from autogluon.tabular)
#   Downloading scikit_learn-1.4.0-1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: networkx<4,>=3.0 in /opt/conda/lib/python3.10/site-packages (from autogluon.tabular) (3.3)
# Collecting autogluon.core==1.1.1 (from autogluon.tabular)
#   Downloading autogluon.core-1.1.1-py3-none-any.whl.metadata (11 kB)
# Collecting autogluon.features==1.1.1 (from autogluon.tabular)
#   Downloading autogluon.features-1.1.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tqdm<5,>=4.38 in /opt/conda/lib/python3.10/site-packages (from autogluon.core==1.1.1->autogluon.tabular) (4.66.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from autogluon.core==1.1.1->autogluon.tabular) (2.32.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from autogluon.core==1.1.1->autogluon.tabular) (3.7.5)
# Requirement already satisfied: boto3<2,>=1.10 in /opt/conda/lib/python3.10/site-packages (from autogluon.core==1.1.1->autogluon.tabular) (1.26.100)
# Collecting autogluon.common==1.1.1 (from autogluon.core==1.1.1->autogluon.tabular)
#   Downloading autogluon.common-1.1.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: psutil<6,>=5.7.3 in /opt/conda/lib/python3.10/site-packages (from autogluon.common==1.1.1->autogluon.core==1.1.1->autogluon.tabular) (5.9.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from autogluon.common==1.1.1->autogluon.core==1.1.1->autogluon.tabular) (70.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas<2.3.0,>=2.0.0->autogluon.tabular) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<2.3.0,>=2.0.0->autogluon.tabular) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas<2.3.0,>=2.0.0->autogluon.tabular) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<1.4.1,>=1.3.0->autogluon.tabular) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<1.4.1,>=1.3.0->autogluon.tabular) (3.5.0)
# Collecting botocore<1.30.0,>=1.29.100 (from boto3<2,>=1.10->autogluon.core==1.1.1->autogluon.tabular)
#   Downloading botocore-1.29.165-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.1->autogluon.tabular) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.1->autogluon.tabular) (0.6.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<2.3.0,>=2.0.0->autogluon.tabular) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.tabular) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.tabular) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.tabular) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.tabular) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.tabular) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.tabular) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.tabular) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->autogluon.core==1.1.1->autogluon.tabular) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->autogluon.core==1.1.1->autogluon.tabular) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->autogluon.core==1.1.1->autogluon.tabular) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->autogluon.core==1.1.1->autogluon.tabular) (2024.8.30)
# Downloading autogluon.tabular-1.1.1-py3-none-any.whl (312 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.1/312.1 kB 10.3 MB/s eta 0:00:00
# Downloading autogluon.core-1.1.1-py3-none-any.whl (234 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.8/234.8 kB 12.4 MB/s eta 0:00:00
# Downloading autogluon.features-1.1.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 3.6 MB/s eta 0:00:00
# Downloading autogluon.common-1.1.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 3.5 MB/s eta 0:00:00
# Downloading scikit_learn-1.4.0-1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 74.4 MB/s eta 0:00:00
# Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 40.5 MB/s eta 0:00:00
# Downloading botocore-1.29.165-py3-none-any.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 92.6 MB/s eta 0:00:00
# Installing collected packages: scipy, scikit-learn, botocore, autogluon.common, autogluon.features, autogluon.core, autogluon.tabular
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.35.23
#     Uninstalling botocore-1.35.23:
#       Successfully uninstalled botocore-1.35.23
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.15.1 requires botocore<1.35.24,>=1.35.16, but you have botocore 1.29.165 which is incompatible.
# bigframes 0.22.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.10.0, but you have google-cloud-bigquery 2.34.4 which is incompatible.
# bigframes 0.22.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.44.0 which is incompatible.
# bigframes 0.22.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.3 which is incompatible.
# cesium 0.12.3 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.9.2 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tsfresh 0.20.3 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.12.0 which is incompatible.
# Successfully installed autogluon.common-1.1.1 autogluon.core-1.1.1 autogluon.features-1.1.1 autogluon.tabular-1.1.1 botocore-1.29.165 scikit-learn-1.4.0 scipy-1.12.0
# Collecting ray==2.10.0
#   Downloading ray-2.10.0-cp310-cp310-manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from ray==2.10.0) (8.1.7)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from ray==2.10.0) (3.15.1)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from ray==2.10.0) (4.22.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ray==2.10.0) (1.0.8)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ray==2.10.0) (21.3)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/conda/lib/python3.10/site-packages (from ray==2.10.0) (3.20.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from ray==2.10.0) (6.0.2)
# Requirement already satisfied: aiosignal in /opt/conda/lib/python3.10/site-packages (from ray==2.10.0) (1.3.1)
# Requirement already satisfied: frozenlist in /opt/conda/lib/python3.10/site-packages (from ray==2.10.0) (1.4.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from ray==2.10.0) (2.32.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.10.0) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.10.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.10.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.10.0) (0.18.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->ray==2.10.0) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.10.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.10.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.10.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.10.0) (2024.8.30)
# Downloading ray-2.10.0-cp310-cp310-manylinux2014_x86_64.whl (65.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.1/65.1 MB 7.4 MB/s eta 0:00:00
# Installing collected packages: ray
#   Attempting uninstall: ray
#     Found existing installation: ray 2.24.0
#     Uninstalling ray-2.24.0:
#       Successfully uninstalled ray-2.24.0
# Successfully installed ray-2.10.0

# %%
# !pip uninstall -y scikit-learn
# !pip install -U scikit-learn
# import sklearn
# sklearn.__version__

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, accuracy_score
from autogluon.tabular import TabularPredictor
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle
import shutil
import os

warnings.filterwarnings('ignore')

# %%
class CFG:
    train_path = '/kaggle/input/playground-series-s4e11/train.csv'
    test_path = '/kaggle/input/playground-series-s4e11/test.csv'
    sample_sub_path = '/kaggle/input/playground-series-s4e11/sample_submission.csv'
    original_data_path = '/kaggle/input/depression-surveydataset-for-analysis/final_depression_dataset_1.csv'
    
    target = 'Depression'
    n_folds = 5
    seed = 42
    time_limit = 3600 * 5

# %% [markdown]
# # Loading data and predefining folds

# %%
# %%time
# train = pd.read_csv(CFG.train_path, index_col='id')
# test = pd.read_csv(CFG.test_path, index_col='id')
# original = pd.read_csv(CFG.original_data_path)

train = pd.read_csv('/kaggle/input/playground-series-s4e11/train.csv')
test = pd.read_csv('/kaggle/input/playground-series-s4e11/test.csv')
sample = pd.read_csv('/kaggle/input/playground-series-s4e11/sample_submission.csv')
original = pd.read_csv('/kaggle/input/depression-surveydataset-for-analysis/final_depression_dataset_1.csv')

original['Depression'] = original['Depression'].map({
    'No': 0,
    'Yes': 1
})

train = train.drop('id',axis=1)
test = test.drop('id',axis=1)

train = pd.concat(objs=[train, original], ignore_index=True)
# Out:
# CPU times: user 646 ms, sys: 97 ms, total: 743 ms
# Wall time: 980 ms

# %%
def clean_columns(df, column, valid_categories):
    df[column] = df[column].apply(lambda x : x if x in valid_categories else 'Noise')
    return df

valid_sleep_duration = ["Less than 5 hours", "5-6 hours", "6-7 hours", "7-8 hours", "More than 8 hours"]
valid_dietary_habits = ['Healthy', 'Moderate', 'Unhealthy']

train = clean_columns(train, 'Sleep Duration', valid_sleep_duration)
train = clean_columns(train, 'Dietary Habits', valid_dietary_habits)
test = clean_columns(test, 'Sleep Duration', valid_sleep_duration)
test = clean_columns(test, 'Dietary Habits', valid_dietary_habits)

# %%
def removieNoise(df, columns, threshold=100):
    
    for column in columns:
        value_counts = df[column].value_counts()
        low_freq_categories = value_counts[value_counts < threshold].index
        df[column] = df[column].apply(lambda x: x if x not in low_freq_categories else 'Other')
    
    return df

train = removieNoise(train, ['Name', 'City', 'Profession', 'Degree'])
test = removieNoise(test, ['Name', 'City', 'Profession', 'Degree'])

# %%
cat_c = [col for col in train.columns if col != 'Depression']
train[cat_c] = train[cat_c].fillna('None').astype('str')
test = test.fillna('None').astype('str')

# %%
skf = StratifiedKFold(n_splits=CFG.n_folds, random_state=CFG.seed, shuffle=True)
split = skf.split(train, train[CFG.target])
for i, (_, val_index) in enumerate(split):
    train.loc[val_index, 'fold'] = i

# %% [markdown]
# # Fitting the predictor

# %%
predictor = TabularPredictor(
    log_file_path='logs.txt',
    log_to_file=True,
    problem_type='binary',
    eval_metric='roc_auc',
    label=CFG.target,
    groups='fold',
    verbosity=2
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20241109_141222"

# %%
# predictor.fit_pseudolabel(
#     train_data=train,
#     pseudo_data=original,
#     time_limit=CFG.time_limit,
#     presets='best_quality',
#     excluded_model_types=['KNN', 'NN', 'XT', 'FASTAI', 'NN_TORCH'],
#     ag_args_fit={
#         'num_gpus': 1, 
#         'num_cpus': 4
#     }
# )

predictor.fit(
    train_data=train,
    time_limit=CFG.time_limit,
    presets='best_quality',
    excluded_model_types=['KNN', 'NN', 'XT', 'FASTAI', 'NN_TORCH']
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.14
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu Jun 27 20:43:36 UTC 2024
# CPU Count:          4
# Memory Avail:       30.15 GB / 31.36 GB (96.2%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 4500s of the 18000s of remaining time (25%).
# 2024-11-09 14:12:22,528	INFO util.py:124 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-11-09 14:12:26,336	INFO worker.py:1752 -- Started a local Ray instance.
# 		Context path: "AutogluonModels/ag-20241109_141222/ds_sub_fit/sub_fit_ho"
# (_dystack pid=183) Running DyStack sub-fit ...
# (_dystack pid=183) Values in column 'fold' used as split folds instead of being automatically set. Bagged models will have 5 splits.
# (_dystack pid=183) Beginning AutoGluon training ... Time limit = 4494s
# (_dystack pid=183) AutoGluon will save models to "AutogluonModels/ag-20241109_141222/ds_sub_fit/sub_fit_ho"
# (_dystack pid=183) Train Data Rows:    127338
# (_dystack pid=183) Train Data Columns: 19
# (_dystack pid=183) Label Column:       Depression
# (_dystack pid=183) Problem Type:       binary
# (_dystack pid=183) Preprocessing data ...
# (_dystack pid=183) Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# (_dystack pid=183) Using Feature Generators to preprocess the data ...
# (_dystack pid=183) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=183) 	Available Memory:                    30411.59 MB
# (_dystack pid=183) 	Train Data (Original)  Memory Usage: 137.07 MB (0.5% of available memory)
# (_dystack pid=183) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=183) 	Stage 1 Generators:
# (_dystack pid=183) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=183) 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=183) 	Stage 2 Generators:
# (_dystack pid=183) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=183) 	Stage 3 Generators:
# (_dystack pid=183) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=183) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=183) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=183) 	Stage 4 Generators:
# (_dystack pid=183) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=183) 	Stage 5 Generators:
# (_dystack pid=183) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=183) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=183) 		('object', []) : 18 | ['Name', 'Gender', 'Age', 'City', 'Working Professional or Student', ...]
# (_dystack pid=183) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=183) 		('category', [])  : 14 | ['Name', 'Age', 'City', 'Profession', 'Academic Pressure', ...]
# (_dystack pid=183) 		('int', ['bool']) :  4 | ['Gender', 'Working Professional or Student', 'Have you ever had suicidal thoughts ?', 'Family History of Mental Illness']
# (_dystack pid=183) 	2.0s = Fit runtime
# (_dystack pid=183) 	18 features in original data used to generate 18 features in processed data.
# (_dystack pid=183) 	Train Data (Processed) Memory Usage: 2.44 MB (0.0% of available memory)
# (_dystack pid=183) Data preprocessing and feature engineering runtime = 2.28s ...
# (_dystack pid=183) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=183) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=183) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=183) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=183) User-specified model hyperparameters to be fit:
# (_dystack pid=183) {
# (_dystack pid=183) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=183) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=183) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=183) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=183) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=183) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=183) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=183) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=183) }
# (_dystack pid=183) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=183) Excluded models: ['NN_TORCH', 'FASTAI', 'KNN', 'XT'] (Specified by `excluded_model_types`)
# (_dystack pid=183) Fitting 55 L1 models ...
# (_dystack pid=183) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2994.02s of the 4492.15s of remaining time.
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.09%)
# (_dystack pid=183) 	0.9754	 = Validation score   (roc_auc)
# (_dystack pid=183) 	53.29s	 = Training   runtime
# (_dystack pid=183) 	8.23s	 = Validation runtime
# (_dystack pid=183) Fitting model: LightGBM_BAG_L1 ... Training model for up to 2933.87s of the 4432.0s of remaining time.
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.09%)
# (_dystack pid=183) 	0.9742	 = Validation score   (roc_auc)
# (_dystack pid=183) 	44.73s	 = Training   runtime
# (_dystack pid=183) 	6.82s	 = Validation runtime
# (_dystack pid=183) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 2885.16s of the 4383.29s of remaining time.
# (_dystack pid=183) 	Forcing `use_child_oof=False` because `groups` is specified
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.28%)
# (_dystack pid=183) 	0.9719	 = Validation score   (roc_auc)
# (_dystack pid=183) 	132.26s	 = Training   runtime
# (_dystack pid=183) 	9.08s	 = Validation runtime
# (_dystack pid=183) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 2747.55s of the 4245.67s of remaining time.
# (_dystack pid=183) 	Forcing `use_child_oof=False` because `groups` is specified
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.29%)
# (_dystack pid=183) 	0.9723	 = Validation score   (roc_auc)
# (_dystack pid=183) 	125.27s	 = Training   runtime
# (_dystack pid=183) 	8.37s	 = Validation runtime
# (_dystack pid=183) Fitting model: CatBoost_BAG_L1 ... Training model for up to 2617.07s of the 4115.2s of remaining time.
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.10%)
# (_ray_fit pid=1096) 	Ran out of time, early stopping on iteration 1139.
# (_dystack pid=183) 	0.9756	 = Validation score   (roc_auc)
# (_dystack pid=183) 	1953.91s	 = Training   runtime
# (_dystack pid=183) 	2.88s	 = Validation runtime
# (_dystack pid=183) Fitting model: XGBoost_BAG_L1 ... Training model for up to 659.21s of the 2157.34s of remaining time.
# (_ray_fit pid=1094) 	Ran out of time, early stopping on iteration 1131. [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.12%)
# (_dystack pid=183) 	0.9699	 = Validation score   (roc_auc)
# (_dystack pid=183) 	532.81s	 = Training   runtime
# (_dystack pid=183) 	1.57s	 = Validation runtime
# (_dystack pid=183) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 122.36s of the 1620.48s of remaining time.
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.12%)
# (_ray_fit pid=1437) 	Ran out of time, early stopping on iteration 270. Best iteration is:
# (_ray_fit pid=1437) 	[214]	valid_set's binary_logloss: 0.153227
# (_dystack pid=183) 	0.9741	 = Validation score   (roc_auc)
# (_dystack pid=183) 	72.66s	 = Training   runtime
# (_dystack pid=183) 	16.31s	 = Validation runtime
# (_dystack pid=183) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 45.2s of the 1543.33s of remaining time.
# (_ray_fit pid=1440) 	Ran out of time, early stopping on iteration 272. Best iteration is: [repeated 3x across cluster]
# (_ray_fit pid=1440) 	[214]	valid_set's binary_logloss: 0.154801 [repeated 3x across cluster]
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.10%)
# (_ray_fit pid=1589) 	Ran out of time, early stopping on iteration 32.
# (_ray_fit pid=1724) 	Ran out of time, early stopping on iteration 45. [repeated 4x across cluster]
# (_dystack pid=183) 	0.9686	 = Validation score   (roc_auc)
# (_dystack pid=183) 	37.6s	 = Training   runtime
# (_dystack pid=183) 	0.24s	 = Validation runtime
# (_dystack pid=183) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 3.9s of the 1502.02s of remaining time.
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.10%)
# (_ray_fit pid=1781) 	Ran out of time, early stopping on iteration 4. Best iteration is:
# (_ray_fit pid=1781) 	[4]	valid_set's binary_logloss: 0.449482
# (_dystack pid=183) 	0.9489	 = Validation score   (roc_auc)
# (_dystack pid=183) 	7.82s	 = Training   runtime
# (_dystack pid=183) 	0.36s	 = Validation runtime
# (_dystack pid=183) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 1489.56s of remaining time.
# (_ray_fit pid=1898) 	Ran out of time, early stopping on iteration 37. Best iteration is: [repeated 4x across cluster]
# (_ray_fit pid=1898) 	[37]	valid_set's binary_logloss: 0.319959 [repeated 4x across cluster]
# (_dystack pid=183) 	Ensemble Weights: {'CatBoost_BAG_L1': 0.5, 'LightGBMXT_BAG_L1': 0.458, 'RandomForestEntr_BAG_L1': 0.042}
# (_dystack pid=183) 	0.9762	 = Validation score   (roc_auc)
# (_dystack pid=183) 	5.53s	 = Training   runtime
# (_dystack pid=183) 	0.02s	 = Validation runtime
# (_dystack pid=183) Excluded models: ['NN_TORCH', 'FASTAI', 'KNN', 'XT'] (Specified by `excluded_model_types`)
# (_dystack pid=183) Fitting 55 L2 models ...
# (_dystack pid=183) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1483.99s of the 1483.95s of remaining time.
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.19%)
# (_dystack pid=183) 	0.9752	 = Validation score   (roc_auc)
# (_dystack pid=183) 	39.09s	 = Training   runtime
# (_dystack pid=183) 	3.33s	 = Validation runtime
# (_dystack pid=183) Fitting model: LightGBM_BAG_L2 ... Training model for up to 1441.14s of the 1441.1s of remaining time.
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.19%)
# (_dystack pid=183) 	0.9747	 = Validation score   (roc_auc)
# (_dystack pid=183) 	38.83s	 = Training   runtime
# (_dystack pid=183) 	2.43s	 = Validation runtime
# (_dystack pid=183) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 1398.63s of the 1398.59s of remaining time.
# (_dystack pid=183) 	Forcing `use_child_oof=False` because `groups` is specified
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.30%)
# (_dystack pid=183) 	0.9743	 = Validation score   (roc_auc)
# (_dystack pid=183) 	262.96s	 = Training   runtime
# (_dystack pid=183) 	7.19s	 = Validation runtime
# (_dystack pid=183) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 1131.32s of the 1131.28s of remaining time.
# (_dystack pid=183) 	Forcing `use_child_oof=False` because `groups` is specified
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.30%)
# (_dystack pid=183) 	0.9747	 = Validation score   (roc_auc)
# (_dystack pid=183) 	263.53s	 = Training   runtime
# (_dystack pid=183) 	6.82s	 = Validation runtime
# (_dystack pid=183) Fitting model: CatBoost_BAG_L2 ... Training model for up to 862.99s of the 862.94s of remaining time.
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.21%)
# (_ray_fit pid=2698) 	Ran out of time, early stopping on iteration 407.
# (_dystack pid=183) 	0.9759	 = Validation score   (roc_auc)
# (_dystack pid=183) 	366.31s	 = Training   runtime
# (_dystack pid=183) 	0.8s	 = Validation runtime
# (_dystack pid=183) Fitting model: XGBoost_BAG_L2 ... Training model for up to 492.97s of the 492.93s of remaining time.
# (_ray_fit pid=2695) 	Ran out of time, early stopping on iteration 397.
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.26%)
# (_dystack pid=183) 	0.9758	 = Validation score   (roc_auc)
# (_dystack pid=183) 	400.74s	 = Training   runtime
# (_dystack pid=183) 	1.76s	 = Validation runtime
# (_dystack pid=183) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 88.45s of the 88.41s of remaining time.
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.24%)
# (_ray_fit pid=3054) 	Ran out of time, early stopping on iteration 165. Best iteration is:
# (_ray_fit pid=3054) 	[142]	valid_set's binary_logloss: 0.152704
# (_dystack pid=183) 	0.9745	 = Validation score   (roc_auc)
# (_dystack pid=183) 	55.33s	 = Training   runtime
# (_dystack pid=183) 	5.39s	 = Validation runtime
# (_dystack pid=183) Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 29.06s of the 29.02s of remaining time.
# (_ray_fit pid=3052) 	Ran out of time, early stopping on iteration 165. Best iteration is: [repeated 3x across cluster]
# (_ray_fit pid=3052) 	[141]	valid_set's binary_logloss: 0.158094 [repeated 3x across cluster]
# (_dystack pid=183) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.21%)
# (_ray_fit pid=3206) 	Ran out of time, early stopping on iteration 18.
# (_ray_fit pid=3339) 	Ran out of time, early stopping on iteration 27. [repeated 4x across cluster]
# (_dystack pid=183) 	0.9749	 = Validation score   (roc_auc)
# (_dystack pid=183) 	24.58s	 = Training   runtime
# (_dystack pid=183) 	0.27s	 = Validation runtime
# (_dystack pid=183) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 0.35s of remaining time.
# (_dystack pid=183) 	Ensemble Weights: {'CatBoost_BAG_L1': 0.353, 'LightGBMXT_BAG_L1': 0.294, 'CatBoost_BAG_L2': 0.235, 'RandomForestEntr_BAG_L2': 0.059, 'XGBoost_BAG_L2': 0.059}
# (_dystack pid=183) 	0.9762	 = Validation score   (roc_auc)
# (_dystack pid=183) 	8.96s	 = Training   runtime
# (_dystack pid=183) 	0.02s	 = Validation runtime
# (_dystack pid=183) AutoGluon training complete, total runtime = 4503.12s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 402.6 rows/s (25468 batch size)
# (_dystack pid=183) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20241109_141222/ds_sub_fit/sub_fit_ho")
# (_dystack pid=183) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0            XGBoost_BAG_L2       0.975890   0.975811     roc_auc       33.087910      55.636178  3361.075968                 0.687162                1.763401         400.738189            2       True         16
# 1           CatBoost_BAG_L2       0.975743   0.975942     roc_auc       32.657899      54.676947  3326.652419                 0.257151                0.804170         366.314640            2       True         15
# 2       WeightedEnsemble_L3       0.975680   0.976234     roc_auc       35.454528      63.282823  3999.887650                 0.004478                0.024304           8.962896            3       True         19
# 3       WeightedEnsemble_L2       0.975599   0.976196     roc_auc       16.989714      19.510788  2138.000492                 0.003393                0.024049           5.527342            2       True         10
# 4         LightGBMXT_BAG_L2       0.975408   0.975205     roc_auc       32.756762      57.205608  2999.431411                 0.356014                3.332831          39.093632            2       True         11
# 5      CatBoost_r177_BAG_L2       0.975371   0.974886     roc_auc       32.454927      54.143366  2984.917554                 0.054179                0.270589          24.579775            2       True         18
# 6         LightGBMXT_BAG_L1       0.975269   0.975376     roc_auc        2.139052       8.234974    53.289913                 2.139052                8.234974          53.289913            1       True          1
# 7   RandomForestEntr_BAG_L2       0.975112   0.974746     roc_auc       34.505737      60.690948  3223.871925                 2.104989                6.818171         263.534146            2       True         14
# 8   RandomForestGini_BAG_L2       0.975038   0.974323     roc_auc       34.709193      61.059400  3223.293623                 2.308444                7.186623         262.955844            2       True         13
# 9      LightGBMLarge_BAG_L2       0.974984   0.974457     roc_auc       32.988743      59.263261  3015.665980                 0.587995                5.390483          55.328201            2       True         17
# 10          LightGBM_BAG_L2       0.974929   0.974718     roc_auc       32.691306      56.306499  2999.167572                 0.290558                2.433722          38.829793            2       True         12
# 11          CatBoost_BAG_L1       0.974911   0.975584     roc_auc        2.846243       2.877554  1953.914268                 2.846243                2.877554        1953.914268            1       True          5
# 12     LightGBMLarge_BAG_L1       0.974455   0.974109     roc_auc        1.385465      16.312293    72.660325                 1.385465               16.312293          72.660325            1       True          7
# 13          LightGBM_BAG_L1       0.974104   0.974155     roc_auc        0.835354       6.823734    44.730631                 0.835354                6.823734          44.730631            1       True          2
# 14  RandomForestEntr_BAG_L1       0.973187   0.972302     roc_auc       12.001027       8.374211   125.268969                12.001027                8.374211         125.268969            1       True          4
# 15  RandomForestGini_BAG_L1       0.972703   0.971890     roc_auc       12.480344       9.079200   132.257068                12.480344                9.079200         132.257068            1       True          3
# 16           XGBoost_BAG_L1       0.969065   0.969897     roc_auc        0.555942       1.573173   532.805687                 0.555942                1.573173         532.805687            1       True          6
# 17     LightGBM_r131_BAG_L1       0.968390   0.948916     roc_auc        0.095839       0.361156     7.815807                 0.095839                0.361156           7.815807            1       True          9
# 18     CatBoost_r177_BAG_L1       0.968026   0.968590     roc_auc        0.061482       0.236482    37.595111                 0.061482                0.236482          37.595111            1       True          8
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	4552s	 = DyStack   runtime |	13448s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Values in column 'fold' used as split folds instead of being automatically set. Bagged models will have 5 splits.
# Beginning AutoGluon training ... Time limit = 13448s
# AutoGluon will save models to "AutogluonModels/ag-20241109_141222"
# Train Data Rows:    143256
# Train Data Columns: 19
# Label Column:       Depression
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    29631.27 MB
# 	Train Data (Original)  Memory Usage: 154.19 MB (0.5% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('object', []) : 18 | ['Name', 'Gender', 'Age', 'City', 'Working Professional or Student', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 14 | ['Name', 'Age', 'City', 'Profession', 'Academic Pressure', ...]
# 		('int', ['bool']) :  4 | ['Gender', 'Working Professional or Student', 'Have you ever had suicidal thoughts ?', 'Family History of Mental Illness']
# 	2.2s = Fit runtime
# 	18 features in original data used to generate 18 features in processed data.
# 	Train Data (Processed) Memory Usage: 2.74 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 2.71s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Excluded models: ['XT', 'NN_TORCH', 'KNN', 'FASTAI'] (Specified by `excluded_model_types`)
# Fitting 55 L1 models ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 8961.38s of the 13445.42s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	0.9754	 = Validation score   (roc_auc)
# 	54.25s	 = Training   runtime
# 	9.35s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 8900.62s of the 13384.65s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	0.9742	 = Validation score   (roc_auc)
# 	54.26s	 = Training   runtime
# 	8.23s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 8842.11s of the 13326.15s of remaining time.
# 	Forcing `use_child_oof=False` because `groups` is specified
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.31%)
# 	0.972	 = Validation score   (roc_auc)
# 	144.76s	 = Training   runtime
# 	10.94s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 8692.48s of the 13176.52s of remaining time.
# 	Forcing `use_child_oof=False` because `groups` is specified
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.31%)
# 	0.9725	 = Validation score   (roc_auc)
# 	161.66s	 = Training   runtime
# 	9.66s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 8525.53s of the 13009.57s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.08%)
# 	0.9756	 = Validation score   (roc_auc)
# 	4102.27s	 = Training   runtime
# 	3.02s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 4418.16s of the 8902.2s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	0.9748	 = Validation score   (roc_auc)
# 	3113.54s	 = Training   runtime
# 	5.04s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1300.21s of the 5784.25s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	0.9742	 = Validation score   (roc_auc)
# 	88.02s	 = Training   runtime
# 	19.34s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 1207.49s of the 5691.53s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.08%)
# 	0.9757	 = Validation score   (roc_auc)
# 	832.21s	 = Training   runtime
# 	1.58s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 371.29s of the 4855.33s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.08%)
# 	0.9748	 = Validation score   (roc_auc)
# 	210.57s	 = Training   runtime
# 	80.56s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 153.16s of the 4637.2s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.15%)
# 	0.9718	 = Validation score   (roc_auc)
# 	127.32s	 = Training   runtime
# 	0.89s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 22.17s of the 4506.21s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	0.9647	 = Validation score   (roc_auc)
# 	23.29s	 = Training   runtime
# 	3.18s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 896.14s of the 4478.23s of remaining time.
# 	Ensemble Weights: {'CatBoost_r177_BAG_L1': 0.333, 'LightGBMXT_BAG_L1': 0.25, 'CatBoost_BAG_L1': 0.167, 'XGBoost_BAG_L1': 0.167, 'LightGBM_r131_BAG_L1': 0.083}
# 	0.9763	 = Validation score   (roc_auc)
# 	7.79s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Excluded models: ['XT', 'NN_TORCH', 'KNN', 'FASTAI'] (Specified by `excluded_model_types`)
# Fitting 55 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 4470.38s of the 4470.32s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.20%)
# 	0.9753	 = Validation score   (roc_auc)
# 	45.47s	 = Training   runtime
# 	3.67s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 4420.97s of the 4420.91s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.21%)
# 	0.975	 = Validation score   (roc_auc)
# 	44.7s	 = Training   runtime
# 	2.65s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 4372.28s of the 4372.22s of remaining time.
# 	Forcing `use_child_oof=False` because `groups` is specified
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.9738	 = Validation score   (roc_auc)
# 	343.48s	 = Training   runtime
# 	9.23s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 4024.06s of the 4024.0s of remaining time.
# 	Forcing `use_child_oof=False` because `groups` is specified
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.9745	 = Validation score   (roc_auc)
# 	341.02s	 = Training   runtime
# 	8.21s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 3677.87s of the 3677.82s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.23%)
# 	0.976	 = Validation score   (roc_auc)
# 	502.83s	 = Training   runtime
# 	0.75s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 3171.13s of the 3171.08s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.29%)
# 	0.9759	 = Validation score   (roc_auc)
# 	681.42s	 = Training   runtime
# 	1.88s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 2485.68s of the 2485.63s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.26%)
# 	0.9746	 = Validation score   (roc_auc)
# 	78.36s	 = Training   runtime
# 	6.0s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 2403.01s of the 2402.95s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.22%)
# 	0.9762	 = Validation score   (roc_auc)
# 	236.45s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 2162.42s of the 2162.36s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.22%)
# 	0.975	 = Validation score   (roc_auc)
# 	135.29s	 = Training   runtime
# 	14.3s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 2022.07s of the 2022.02s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.9761	 = Validation score   (roc_auc)
# 	158.41s	 = Training   runtime
# 	0.84s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 1859.58s of the 1859.53s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.20%)
# 	0.9757	 = Validation score   (roc_auc)
# 	86.71s	 = Training   runtime
# 	11.55s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 1768.34s of the 1768.28s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.9754	 = Validation score   (roc_auc)
# 	1422.47s	 = Training   runtime
# 	6.67s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 340.57s of the 340.51s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.20%)
# 	0.9761	 = Validation score   (roc_auc)
# 	275.06s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L2 ... Training model for up to 61.41s of the 61.36s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.9744	 = Validation score   (roc_auc)
# 	49.9s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 447.04s of the 6.96s of remaining time.
# 	Ensemble Weights: {'CatBoost_r177_BAG_L1': 0.286, 'CatBoost_r177_BAG_L2': 0.286, 'LightGBMXT_BAG_L1': 0.19, 'XGBoost_BAG_L1': 0.095, 'CatBoost_r9_BAG_L2': 0.095, 'XGBoost_BAG_L2': 0.048}
# 	0.9764	 = Validation score   (roc_auc)
# 	11.98s	 = Training   runtime
# 	0.03s	 = Validation runtime
# AutoGluon training complete, total runtime = 13453.24s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 184.8 rows/s (28652 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20241109_141222")

# %%
predictor.leaderboard(silent=True).style.background_gradient(subset=['score_val'], cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_8a2a6_row0_col1, #T_8a2a6_row1_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8a2a6_row2_col1 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_8a2a6_row3_col1, #T_8a2a6_row4_col1 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_8a2a6_row5_col1 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_8a2a6_row6_col1 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_8a2a6_row7_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_8a2a6_row8_col1 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_8a2a6_row9_col1 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_8a2a6_row10_col1 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_8a2a6_row11_col1 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_8a2a6_row12_col1 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_8a2a6_row13_col1 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_8a2a6_row14_col1 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_8a2a6_row15_col1 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_8a2a6_row16_col1 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_8a2a6_row17_col1 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_8a2a6_row18_col1 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_8a2a6_row19_col1 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_8a2a6_row20_col1 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_8a2a6_row21_col1 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_8a2a6_row22_col1 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_8a2a6_row23_col1 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_8a2a6_row24_col1 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_8a2a6_row25_col1 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_8a2a6_row26_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8a2a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a2a6_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_8a2a6_level0_col1" class="col_heading level0 col1" >score_val</th>
#       <th id="T_8a2a6_level0_col2" class="col_heading level0 col2" >eval_metric</th>
#       <th id="T_8a2a6_level0_col3" class="col_heading level0 col3" >pred_time_val</th>
#       <th id="T_8a2a6_level0_col4" class="col_heading level0 col4" >fit_time</th>
#       <th id="T_8a2a6_level0_col5" class="col_heading level0 col5" >pred_time_val_marginal</th>
#       <th id="T_8a2a6_level0_col6" class="col_heading level0 col6" >fit_time_marginal</th>
#       <th id="T_8a2a6_level0_col7" class="col_heading level0 col7" >stack_level</th>
#       <th id="T_8a2a6_level0_col8" class="col_heading level0 col8" >can_infer</th>
#       <th id="T_8a2a6_level0_col9" class="col_heading level0 col9" >fit_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a2a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a2a6_row0_col0" class="data row0 col0" >WeightedEnsemble_L3</td>
#       <td id="T_8a2a6_row0_col1" class="data row0 col1" >0.976377</td>
#       <td id="T_8a2a6_row0_col2" class="data row0 col2" >roc_auc</td>
#       <td id="T_8a2a6_row0_col3" class="data row0 col3" >155.031338</td>
#       <td id="T_8a2a6_row0_col4" class="data row0 col4" >10000.395332</td>
#       <td id="T_8a2a6_row0_col5" class="data row0 col5" >0.027348</td>
#       <td id="T_8a2a6_row0_col6" class="data row0 col6" >11.981486</td>
#       <td id="T_8a2a6_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_8a2a6_row0_col8" class="data row0 col8" >True</td>
#       <td id="T_8a2a6_row0_col9" class="data row0 col9" >27</td>
#     </tr>
#     <tr>
#       <th id="T_8a2a6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8a2a6_row1_col0" class="data row1 col0" >WeightedEnsemble_L2</td>
#       <td id="T_8a2a6_row1_col1" class="data row1 col1" >0.976343</td>
#       <td id="T_8a2a6_row1_col2" class="data row1 col2" >roc_auc</td>
#       <td id="T_8a2a6_row1_col3" class="data row1 col3" >99.581954</td>
#       <td id="T_8a2a6_row1_col4" class="data row1 col4" >8320.629317</td>
#       <td id="T_8a2a6_row1_col5" class="data row1 col5" >0.028736</td>
#       <td id="T_8a2a6_row1_col6" class="data row1 col6" >7.794327</td>
#       <td id="T_8a2a6_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_8a2a6_row1_col8" class="data row1 col8" >True</td>
#       <td id="T_8a2a6_row1_col9" class="data row1 col9" >12</td>
#     </tr>
#     <tr>
#       <th id="T_8a2a6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8a2a6_row2_col0" class="data row2 col0" >CatBoost_r177_BAG_L2</td>
#       <td id="T_8a2a6_row2_col1" class="data row2 col1" >0.976185</td>
#       <td id="T_8a2a6_row2_col2" class="data row2 col2" >roc_auc</td>
#       <td id="T_8a2a6_row2_col3" class="data row2 col3" >152.277642</td>
#       <td id="T_8a2a6_row2_col4" class="data row2 col4" >9148.584737</td>
#       <td id="T_8a2a6_row2_col5" class="data row2 col5" >0.476778</td>
#       <td id="T_8a2a6_row2_col6" class="data row2 col6" >236.445732</td>
#       <td id="T_8a2a6_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_8a2a6_row2_col8" class="data row2 col8" >True</td>
#       <td id="T_8a2a6_row2_col9" class="data row2 col9" >20</td>
#     </tr>
#     <tr>
#       <th id="T_8a2a6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8a2a6_row3_col0" class="data row3 col0" >CatBoost_r9_BAG_L2</td>
#       <td id="T_8a2a6_row3_col1" class="data row3 col1" >0.976135</td>
#       <td id="T_8a2a6_row3_col2" class="data row3 col2" >roc_auc</td>
#       <td id="T_8a2a6_row3_col3" class="data row3 col3" >152.643374</td>
#       <td id="T_8a2a6_row3_col4" class="data row3 col4" >9070.548631</td>
#       <td id="T_8a2a6_row3_col5" class="data row3 col5" >0.842510</td>
#       <td id="T_8a2a6_row3_col6" class="data row3 col6" >158.409625</td>
#       <td id="T_8a2a6_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_8a2a6_row3_col8" class="data row3 col8" >True</td>
#       <td id="T_8a2a6_row3_col9" class="data row3 col9" >22</td>
#     </tr>
#     <tr>
#       <th id="T_8a2a6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8a2a6_row4_col0" class="data row4 col0" >CatBoost_r137_BAG_L2</td>
#       <td id="T_8a2a6_row4_col1" class="data row4 col1" >0.976111</td>
#       <td id="T_8a2a6_row4_col2" class="data row4 col2" >roc_auc</td>
#       <td id="T_8a2a6_row4_col3" class="data row4 col3" >152.595981</td>
#       <td id="T_8a2a6_row4_col4" class="data row4 col4" >9187.201287</td>
#       <td id="T_8a2a6_row4_col5" class="data row4 col5" >0.795117</td>
#       <td id="T_8a2a6_row4_col6" class="data row4 col6" >275.062281</td>
#       <td id="T_8a2a6_row4_col7" class="data row4 col7" >2</td>
#       <td id="T_8a2a6_row4_col8" class="data row4 col8" >True</td>
#       <td id="T_8a2a6_row4_col9" class="data row4 col9" >25</td>
#     </tr>
#     <tr>
#       <th id="T_8a2a6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8a2a6_row5_col0" class="data row5 col0" >CatBoost_BAG_L2</td>
#       <td id="T_8a2a6_row5_col1" class="data row5 col1" >0.976011</td>
#       <td id="T_8a2a6_row5_col2" class="data row5 col2" >roc_auc</td>
#       <td id="T_8a2a6_row5_col3" class="data row5 col3" >152.552102</td>
#       <td id="T_8a2a6_row5_col4" class="data row5 col4" >9414.971274</td>
#       <td id="T_8a2a6_row5_col5" class="data row5 col5" >0.751238</td>
#       <td id="T_8a2a6_row5_col6" class="data row5 col6" >502.832268</td>
#       <td id="T_8a2a6_row5_col7" class="data row5 col7" >2</td>
#       <td id="T_8a2a6_row5_col8" class="data row5 col8" >True</td>
#       <td id="T_8a2a6_row5_col9" class="data row5 col9" >17</td>
#     </tr>
#     <tr>
#       <th id="T_8a2a6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8a2a6_row6_col0" class="data row6 col0" >XGBoost_BAG_L2</td>
#       <td id="T_8a2a6_row6_col1" class="data row6 col1" >0.975933</td>
#       <td id="T_8a2a6_row6_col2" class="data row6 col2" >roc_auc</td>
#       <td id="T_8a2a6_row6_col3" class="data row6 col3" >153.684702</td

# %% [markdown]
# # Visualizing the ensemble weights

# %%
# def get_ensemble_weights():
#     ensemble_weights = {}
#     with open('logs.txt', 'rb') as f:
#         prev_line = b''
#         for line in f.readlines():
#             if b'Ensemble Weights:' in line:
#                 try:
#                     name = prev_line.split(b'Fitting model: ')[1]
#                     name = name.split(b'...')[0]
#                     name = name.decode('utf-8')
#                     temp_ensemble_weights = line.split(b'Ensemble Weights: ')[1]
#                     temp_ensemble_weights = temp_ensemble_weights.split(b'\n')[0]
#                     temp_ensemble_weights = eval(temp_ensemble_weights)
#                     ensemble_weights[name] = temp_ensemble_weights
#                 except:
#                     continue
#             prev_line = line
#     return ensemble_weights

# get_ensemble_weights()

# %%
# ensemble_weights = get_ensemble_weights()

# for key, value in ensemble_weights.items():
#     plt.figure(figsize=(6, 6))
#     plt.pie(value.values(), labels=value.keys(), autopct='%1.1f%%', colors=sns.color_palette('Set2', len(value)))
#     plt.title(key)
#     plt.tight_layout()
#     plt.show()

# %% [markdown]
# # Collecting and saving OOF files

# %%
def save_pred_probs(pred_probs, cv_score, name, type, is_ensemble):
    base_path = 'oof_pred_probs' if type == 'oof' else 'test_pred_probs'
    base_path = '.' if is_ensemble else base_path
    with open(f'{base_path}/{name}_{type}_pred_probs_{cv_score:.6f}.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)

def save_submission(test_pred_probs, score):
    sub = pd.read_csv(CFG.sample_sub_path)
    sub[CFG.target] = np.where(test_pred_probs > 0.5, 1, 0)
    sub.to_csv(f'submission.csv', index=False)
    
os.makedirs('oof_pred_probs', exist_ok=True)
os.makedirs('test_pred_probs', exist_ok=True)

# %%
oof_pred_probs = {}
test_pred_probs = {}

# %%
best_model = predictor.model_best
test_pred_probs = predictor.predict_proba_multi(test)
for model in predictor.model_names():
    model_oof_pred_probs = predictor.predict_proba_oof(model).values[:, 1]
    model_test_pred_probs = test_pred_probs[model].values[:, 1]
    
    cv_score = roc_auc_score(train[CFG.target], model_oof_pred_probs)
    if model != best_model:
        save_pred_probs(model_oof_pred_probs, cv_score, model, 'oof', False)
        save_pred_probs(model_test_pred_probs, cv_score, model, 'test', False)
    else:
        save_pred_probs(model_oof_pred_probs, cv_score, model, 'oof', True)
        save_pred_probs(model_test_pred_probs, cv_score, model, 'test', True)
        save_submission(model_test_pred_probs, cv_score)
        
    oof_pred_probs[model] = model_oof_pred_probs
    test_pred_probs[model] = model_test_pred_probs

# %% [markdown]
# # Visualizing the results

# %%
# scores = {}
# split = StratifiedKFold(n_splits=CFG.n_folds, random_state=CFG.seed, shuffle=True).split(train, train[CFG.target])
# for fold_idx, (train_index, val_index) in enumerate(split):
#     for model in predictor.model_names():
#         fold_score = roc_auc_score(train.loc[val_index, CFG.target], oof_pred_probs[model][val_index])
# #         fold_score = accuracy_score(train.loc[val_index, CFG.target], np.where(oof_pred_probs[model][val_index]>0.5, 1, 0))
#         if model not in scores:
#             scores[model] = []
#         scores[model].append(fold_score)

# %%
# scores = pd.DataFrame(scores)
# mean_scores = scores.mean().sort_values(ascending=False)
# order = scores.mean().sort_values(ascending=False).index.tolist()

# min_score = mean_scores.min()
# max_score = mean_scores.max()
# padding = (max_score - min_score) * 0.5
# lower_limit = min_score - padding
# upper_limit = max_score + padding

# fig, axs = plt.subplots(1, 2, figsize=(15, scores.shape[1] * 0.4))

# sns.boxplot(data=scores, order=order, ax=axs[0], orient='h', palette='RdYlGn_r')
# axs[0].set_title('Fold AUC')
# axs[0].set_xlabel('')
# axs[0].set_ylabel('')

# barplot = sns.barplot(x=mean_scores.values, y=mean_scores.index, ax=axs[1], palette='RdYlGn_r')
# axs[1].set_title('Average Accuracy')
# axs[1].set_xlabel('')
# axs[1].set_xlim(left=lower_limit, right=upper_limit)
# axs[1].set_ylabel('')

# for i, score in enumerate(mean_scores.values):
#     barplot.text(score, i, round(score, 6), va='center')

# plt.tight_layout()
# plt.show()

# %%
shutil.rmtree("AutogluonModels")
